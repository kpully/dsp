# %%
import pandas as pd

# %%
dir = '/Users/kpully/ds/metis/prework/dsp/python/faculty.csv'

# %%
data = pd.read_csv(dir)
df = pd.DataFrame(data)

# %%
df.columns = ['name', 'degree', 'title', 'email']
df
# Out:
#                          name               degree  \
# 0         Scarlett L. Bellamy                Sc.D.
# 1            Warren B. Bilker                Ph.D.
# 2             Matthew W Bryan                  PhD
# 3                  Jinbo Chen                Ph.D.
# 4           Susan S Ellenberg                Ph.D.
# 5          Jonas H. Ellenberg                Ph.D.
# 6                    Rui Feng                 Ph.D
# 7          Benjamin C. French                  PhD
# 8          Phyllis A. Gimotty                 Ph.D
# 9                Wensheng Guo                 Ph.D
# 10                Yenchih Hsu                Ph.D.
# 11          Rebecca A Hubbard                  PhD
# 12             Wei-Ting Hwang                Ph.D.
# 13          Marshall M. Joffe          MD MPH Ph.D
# 14          J. Richard Landis   B.S.Ed. M.S. Ph.D.
# 15                   Yimei Li                Ph.D.
# 16                 Mingyao Li                Ph.D.
# 17                 Hongzhe Li                 Ph.D
# 18         A. Russell Localio     JD MA MPH MS PhD
# 19              Nandita Mitra                Ph.D.
# 20        Knashawn H. Morales                Sc.D.
# 21       Kathleen Joy Propert                Sc.D.
# 22               Mary E. Putt              PhD ScD
# 23       Sarah Jane Ratcliffe                Ph.D.
# 24        Michelle Elana Ross                  PhD
# 25               Jason A. Roy                Ph.D.
# 26             Mary D. Sammel                Sc.D.
# 27            Pamela Ann Shaw                  PhD
# 28  Russell Takeshi Shinohara                    0
# 29              Haochang Shou                Ph.D.
# 30             Justine Shults                Ph.D.
# 31        Alisa Jane Stephens                Ph.D.
# 32         Andrea Beth Troxel                  ScD
# 33                   Rui Xiao                  PhD
# 34        Sharon Xiangwen Xie                Ph.D.
# 35                  Dawei Xie                  PhD
# 36           Wei (Peter) Yang                Ph.D.
#
#                                    title                        email
# 0   Associate Professor of Biostatistics  bellamys@mail.med.upenn.edu
# 1             Professor of Biostatistics             warren@upenn.edu
# 2   Assistant Professor of Biostatistics            bryanma@upenn.edu
# 3   Associate Professor of Biostatistics           jinboche@upenn.edu
# 4             Professor of Biostatistics           sellenbe@upenn.edu
# 5             Professor of Biostatistics  jellenbe@mail.med.upenn.edu
# 6   Assistant Professor of Biostatistics            ruifeng@upenn.edu
# 7   Associate Professor of Biostatistics  bcfrench@mail.med.upenn.edu
# 8             Professor of Biostatistics           pgimotty@upenn.edu
# 9             Professor of Biostatistics      wguo@mail.med.upenn.edu
# 10  Assistant Professor of Biostatistics      hsu9@mail.med.upenn.edu
# 11  Associate Professor of Biostatistics     rhubb@mail.med.upenn.edu
# 12  Associate Professor of Biostatistics    whwang@mail.med.upenn.edu
# 13            Professor of Biostatistics    mjoffe@mail.med.upenn.edu
# 14            Professor of Biostatistics  jrlandis@mail.med.upenn.edu
# 15  Assistant Professor of Biostatistics          liy3@email.chop.edu
# 16  Associate Professor of Biostatistics   mingyao@mail.med.upenn.edu
# 17            Professor of Biostatistics            hongzhe@upenn.edu
# 18  Associate Professor of Biostatistics           rlocalio@upenn.edu
# 19  Associate Professor of Biostatistics  nanditam@mail.med.upenn.edu
# 20  Associate Professor of Biostatistics  knashawn@mail.med.upenn.edu
# 21            Professor of Biostatistics   propert@mail.med.upenn.edu
# 22            Professor of Biostatistics     mputt@mail.med.upenn.edu
# 23  Associate Professor of Biostatistics           sratclif@upenn.edu
# 24  Assistant Professor is Biostatistics           michross@upenn.edu
# 25  Associate Professor of Biostatistics     jaroy@mail.med.upenn.edu
# 26            Professor of Biostatistics   msammel@cceb.med.upenn.edu
# 27  Assistant Professor of Biostatistics              shawp@upenn.edu
# 28  Assistant Professor of Biostatistics      rshi@mail.med.upenn.edu
# 29  Assistant Professor of Biostatistics     hshou@mail.med.upenn.edu
# 30            Professor of Biostatistics   jshults@mail.med.upenn.edu
# 31  Assistant Professor of Biostatistics  alisaste@mail.med.upenn.edu
# 32            Professor of Biostatistics   atroxel@mail.med.upenn.edu
# 33  Assistant Professor of Biostatistics     rxiao@mail.med.upenn.edu
# 34  Associate Professor of Biostatistics      sxie@mail.med.upenn.edu
# 35  Assistant Professor of Biostatistics               dxie@upenn.edu
# 36  Assistant Professor of Biostatistics   weiyang@mail.med.upenn.edu

# %%
titles_unique = set()
titles_all = list()
for title in df.title:
    of = title.find('of ')
    title = title[:of]
    #print title
    titles_all.append(title.strip())
    titles_unique.add(title.strip())

# %%
titles_all.count('Professor')
# Out:
# 13

# %%
len(titles_unique)
titles_unique
# Out:
# {'Assistant Professor',
#  'Assistant Professor is Biostatistic',
#  'Associate Professor',
#  'Professor'}

# %%
degrees_unique = set()
degrees_all = list()
for degree in df.degree:
    degree_list = degree.lower().strip().replace('.', '').split(' ')
    for degree in degree_list:
        degrees_unique.add(degree)
        degrees_all.append(degree)

# %%
degrees_unique.remove('0')

# %%
print len(degrees_unique)
print degrees_unique
# Out:
# 8
# set(['md', 'ma', 'scd', 'bsed', 'phd', 'mph', 'ms', 'jd'])

# %%
print "PhDs: " + str(degrees_all.count('phd'))
print "MDs: " + str(degrees_all.count('md'))
print "MAs: " + str(degrees_all.count('ma'))
print "BSEds: " + str(degrees_all.count('bsed'))
print "JDs: " + str(degrees_all.count('jd'))
print "MPHs: " + str(degrees_all.count('mph'))
print "SCDs: " + str(degrees_all.count('scd'))
print "MSs: " + str(degrees_all.count('ms'))
# Out:
# PhDs: 31
# MDs: 1
# MAs: 1
# BSEds: 1
# JDs: 1
# MPHs: 2
# SCDs: 6
# MSs: 2

# %%
print 31+1+1+1+2+6+2
# Out:
# 44

# %%
#df.email

# %%
domains = set()
for email in df.email:
    cutoff = email.find('@')
    domain = email[cutoff:]
    domains.add(domain)
domains
# Out:
# {'@cceb.med.upenn.edu', '@email.chop.edu', '@mail.med.upenn.edu', '@upenn.edu'}

# %%
df.email.to_csv('emails.csv')
#how to get it to a list without the index?

# %%
emails = df.email.tolist

# %%
#emails

# %%
new_dict = dict()
df.head()
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email
# 0  bellamys@mail.med.upenn.edu
# 1             warren@upenn.edu
# 2            bryanma@upenn.edu
# 3           jinboche@upenn.edu
# 4           sellenbe@upenn.edu

# %%
new_dict = {df.name: df.degree}
for row in df:
    new_dict = {df.name: [df.degree, df.title, df.email]}
new_dict
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-8c45e57ed483> in <module>()
# ----> 1 new_dict = {df.name: df.degree}
#       2 for row in df:
#       3     new_dict = {df.name: [df.degree, df.title, df.email]}
#       4 new_dict
#
# /Users/kpully/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __hash__(self)
#     799     def __hash__(self):
#     800         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# --> 801                         ' hashed'.format(self.__class__.__name__))
#     802
#     803     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
df.set_index(df.name).to_dict()
# Out:
# {'degree': {'A. Russell Localio': ' JD MA MPH MS PhD',
#   'Alisa Jane Stephens': ' Ph.D.',
#   'Andrea Beth Troxel': ' ScD',
#   'Benjamin C. French': ' PhD',
#   'Dawei Xie': ' PhD',
#   'Haochang Shou': ' Ph.D.',
#   'Hongzhe Li': ' Ph.D',
#   'J. Richard Landis': ' B.S.Ed. M.S. Ph.D.',
#   'Jason A. Roy': ' Ph.D.',
#   'Jinbo Chen': ' Ph.D.',
#   'Jonas H. Ellenberg': ' Ph.D.',
#   'Justine Shults': ' Ph.D.',
#   'Kathleen Joy Propert': ' Sc.D.',
#   'Knashawn H. Morales': ' Sc.D.',
#   'Marshall M. Joffe': ' MD MPH Ph.D',
#   'Mary D. Sammel': ' Sc.D.',
#   'Mary E. Putt': ' PhD ScD',
#   'Matthew W Bryan': ' PhD',
#   'Michelle Elana Ross': ' PhD',
#   'Mingyao Li': ' Ph.D.',
#   'Nandita Mitra': ' Ph.D.',
#   'Pamela Ann Shaw': ' PhD',
#   'Phyllis A. Gimotty': ' Ph.D',
#   'Rebecca A Hubbard': ' PhD',
#   'Rui Feng': ' Ph.D',
#   'Rui Xiao': ' PhD',
#   'Russell Takeshi Shinohara': '0',
#   'Sarah Jane Ratcliffe': ' Ph.D.',
#   'Scarlett L. Bellamy': ' Sc.D.',
#   'Sharon Xiangwen Xie': ' Ph.D.',
#   'Susan S Ellenberg': ' Ph.D.',
#   'Warren B. Bilker': 'Ph.D.',
#   'Wei (Peter) Yang': ' Ph.D.',
#   'Wei-Ting Hwang': ' Ph.D.',
#   'Wensheng Guo': ' Ph.D',
#   'Yenchih Hsu': ' Ph.D.',
#   'Yimei Li': ' Ph.D.'},
#  'email': {'A. Russell Localio': 'rlocalio@upenn.edu',
#   'Alisa Jane Stephens': 'alisaste@mail.med.upenn.edu',
#   'Andrea Beth Troxel': 'atroxel@mail.med.upenn.edu',
#   'Benjamin C. French': 'bcfrench@mail.med.upenn.edu',
#   'Dawei Xie': 'dxie@upenn.edu',
#   'Haochang Shou': 'hshou@mail.med.upenn.edu',
#   'Hongzhe Li': 'hongzhe@upenn.edu',
#   'J. Richard Landis': 'jrlandis@mail.med.upenn.edu',
#   'Jason A. Roy': 'jaroy@mail.med.upenn.edu',
#   'Jinbo Chen': 'jinboche@upenn.edu',
#   'Jonas H. Ellenberg': 'jellenbe@mail.med.upenn.edu',
#   'Justine Shults': 'jshults@mail.med.upenn.edu',
#   'Kathleen Joy Propert': 'propert@mail.med.upenn.edu',
#   'Knashawn H. Morales': 'knashawn@mail.med.upenn.edu',
#   'Marshall M. Joffe': 'mjoffe@mail.med.upenn.edu',
#   'Mary D. Sammel': 'msammel@cceb.med.upenn.edu',
#   'Mary E. Putt': 'mputt@mail.med.upenn.edu',
#   'Matthew W Bryan': 'bryanma@upenn.edu',
#   'Michelle Elana Ross': 'michross@upenn.edu',
#   'Mingyao Li': 'mingyao@mail.med.upenn.edu',
#   'Nandita Mitra': 'nanditam@mail.med.upenn.edu',
#   'Pamela Ann Shaw': 'shawp@upenn.edu',
#   'Phyllis A. Gimotty': 'pgimotty@upenn.edu',
#   'Rebecca A Hubbard': 'rhubb@mail.med.upenn.edu',
#   'Rui Feng': 'ruifeng@upenn.edu',
#   'Rui Xiao': 'rxiao@mail.med.upenn.edu',
#   'Russell Takeshi Shinohara': 'rshi@mail.med.upenn.edu',
#   'Sarah Jane Ratcliffe': 'sratclif@upenn.edu',
#   'Scarlett L. Bellamy': 'bellamys@mail.med.upenn.edu',
#   'Sharon Xiangwen Xie': 'sxie@mail.med.upenn.edu',
#   'Susan S Ellenberg': 'sellenbe@upenn.edu',
#   'Warren B. Bilker': 'warren@upenn.edu',
#   'Wei (Peter) Yang': 'weiyang@mail.med.upenn.edu',
#   'Wei-Ting Hwang': 'whwang@mail.med.upenn.edu',
#   'Wensheng Guo': 'wguo@mail.med.upenn.edu',
#   'Yenchih Hsu': 'hsu9@mail.med.upenn.edu',
#   'Yimei Li': 'liy3@email.chop.edu'},
#  'name': {'A. Russell Localio': 'A. Russell Localio',
#   'Alisa Jane Stephens': 'Alisa Jane Stephens',
#   'Andrea Beth Troxel': 'Andrea Beth Troxel',
#   'Benjamin C. French': 'Benjamin C. French',
#   'Dawei Xie': 'Dawei Xie',
#   'Haochang Shou': 'Haochang Shou',
#   'Hongzhe Li': 'Hongzhe Li',
#   'J. Richard Landis': 'J. Richard Landis',
#   'Jason A. Roy': 'Jason A. Roy',
#   'Jinbo Chen': 'Jinbo Chen',
#   'Jonas H. Ellenberg': 'Jonas H. Ellenberg',
#   'Justine Shults': 'Justine Shults',
#   'Kathleen Joy Propert': 'Kathleen Joy Propert',
#   'Knashawn H. Morales': 'Knashawn H. Morales',
#   'Marshall M. Joffe': 'Marshall M. Joffe',
#   'Mary D. Sammel': 'Mary D. Sammel',
#   'Mary E. Putt': 'Mary E. Putt',
#   'Matthew W Bryan': 'Matthew W Bryan',
#   'Michelle Elana Ross': 'Michelle Elana Ross',
#   'Mingyao Li': 'Mingyao Li',
#   'Nandita Mitra': 'Nandita Mitra',
#   'Pamela Ann Shaw': 'Pamela Ann Shaw',
#   'Phyllis A. Gimotty': 'Phyllis A. Gimotty',
#   'Rebecca A Hubbard': 'Rebecca A Hubbard',
#   'Rui Feng': 'Rui Feng',
#   'Rui Xiao': 'Rui Xiao',
#   'Russell Takeshi Shinohara': 'Russell Takeshi Shinohara',
#   'Sarah Jane Ratcliffe': 'Sarah Jane Ratcliffe',
#   'Scarlett L. Bellamy': 'Scarlett L. Bellamy',
#   'Sharon Xiangwen Xie': 'Sharon Xiangwen Xie',
#   'Susan S Ellenberg': 'Susan S Ellenberg',
#   'Warren B. Bilker': 'Warren B. Bilker',
#   'Wei (Peter) Yang': 'Wei (Peter) Yang',
#   'Wei-Ting Hwang': 'Wei-Ting Hwang',
#   'Wensheng Guo': 'Wensheng Guo',
#   'Yenchih Hsu': 'Yenchih Hsu',
#   'Yimei Li': 'Yimei Li'},
#  'title': {'A. Russell Localio': 'Associate Professor of Biostatistics',
#   'Alisa Jane Stephens': 'Assistant Professor of Biostatistics',
#   'Andrea Beth Troxel': 'Professor of Biostatistics',
#   'Benjamin C. French': 'Associate Professor of Biostatistics',
#   'Dawei Xie': 'Assistant Professor of Biostatistics',
#   'Haochang Shou': 'Assistant Professor of Biostatistics',
#   'Hongzhe Li': 'Professor of Biostatistics',
#   'J. Richard Landis': 'Professor of Biostatistics',
#   'Jason A. Roy': 'Associate Professor of Biostatistics',
#   'Jinbo Chen': 'Associate Professor of Biostatistics',
#   'Jonas H. Ellenberg': 'Professor of Biostatistics',
#   'Justine Shults': 'Professor of Biostatistics',
#   'Kathleen Joy Propert': 'Professor of Biostatistics',
#   'Knashawn H. Morales': 'Associate Professor of Biostatistics',
#   'Marshall M. Joffe': 'Professor of Biostatistics',
#   'Mary D. Sammel': 'Professor of Biostatistics',
#   'Mary E. Putt': 'Professor of Biostatistics',
#   'Matthew W Bryan': 'Assistant Professor of Biostatistics',
#   'Michelle Elana Ross': 'Assistant Professor is Biostatistics',
#   'Mingyao Li': 'Associate Professor of Biostatistics',
#   'Nandita Mitra': 'Associate Professor of Biostatistics',
#   'Pamela Ann Shaw': 'Assistant Professor of Biostatistics',
#   'Phyllis A. Gimotty': 'Professor of Biostatistics',
#   'Rebecca A Hubbard': 'Associate Professor of Biostatistics',
#   'Rui Feng': 'Assistant Professor of Biostatistics',
#   'Rui Xiao': 'Assistant Professor of Biostatistics',
#   'Russell Takeshi Shinohara': 'Assistant Professor of Biostatistics',
#   'Sarah Jane Ratcliffe': 'Associate Professor of Biostatistics',
#   'Scarlett L. Bellamy': 'Associate Professor of Biostatistics',
#   'Sharon Xiangwen Xie': 'Associate Professor of Biostatistics',
#   'Susan S Ellenberg': 'Professor of Biostatistics',
#   'Warren B. Bilker': 'Professor of Biostatistics',
#   'Wei (Peter) Yang': 'Assistant Professor of Biostatistics',
#   'Wei-Ting Hwang': 'Associate Professor of Biostatistics',
#   'Wensheng Guo': 'Professor of Biostatistics',
#   'Yenchih Hsu': 'Assistant Professor of Biostatistics',
#   'Yimei Li': 'Assistant Professor of Biostatistics'}}

# %%
first_names = list()
last_names = list()
for name in df.name:
    space1 = name.find(' ')
    first_name = name[:space1]
    remaining_name = name[space1 + 1:]
    space2 = remaining_name.find(' ')
    last_name = remaining_name[space2+1:]
    #print 'BREAKDOWN: original name = ' + name + ' / first name = ' + first_name + ' / last name = ' + last_name
    first_names.append(first_name)
    last_names.append(last_name)
df['first_name'] = first_names
df['last_name'] = last_names
df.head(6)
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
# 5   Jonas H. Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email first_name  last_name
# 0  bellamys@mail.med.upenn.edu   Scarlett    Bellamy
# 1             warren@upenn.edu     Warren     Bilker
# 2            bryanma@upenn.edu    Matthew      Bryan
# 3           jinboche@upenn.edu      Jinbo       Chen
# 4           sellenbe@upenn.edu      Susan  Ellenberg
# 5  jellenbe@mail.med.upenn.edu      Jonas  Ellenberg

# %%
new_dict = dict()
for row in df:
    print df.last_name
    #key = df.last_name
    #value = df.degree
    #new_dict[key] = value
# Out:
# 0       Bellamy
# 1        Bilker
# 2         Bryan
# 3          Chen
# 4     Ellenberg
# 5     Ellenberg
# 6          Feng
# 7        French
# 8       Gimotty
# 9           Guo
# 10          Hsu
# 11      Hubbard
# 12        Hwang
# 13        Joffe
# 14       Landis
# 15           Li
# 16           Li
# 17           Li
# 18      Localio
# 19        Mitra
# 20      Morales
# 21      Propert
# 22         Putt
# 23    Ratcliffe
# 24         Ross
# 25          Roy
# 26       Sammel
# 27         Shaw
# 28    Shinohara
# 29         Shou
# 30       Shults
# 31     Stephens
# 32       Troxel
# 33         Xiao
# 34          Xie
# 35          Xie
# 36         Yang
# Name: last_name, dtype: object
# 0       Bellamy
# 1        Bilker
# 2         Bryan
# 3          Chen
# 4     Ellenberg
# 5     Ellenberg
# 6          Feng
# 7        French
# 8       Gimotty
# 9           Guo
# 10          Hsu
# 11      Hubbard
# 12        Hwang
# 13        Joffe
# 14       Landis
# 15           Li
# 16           Li
# 17           Li
# 18      Localio
# 19        Mitra
# 20      Morales
# 21      Propert
# 22         Putt
# 23    Ratcliffe
# 24         Ross
# 25          Roy
# 26       Sammel
# 27         Shaw
# 28    Shinohara
# 29         Shou
# 30       Shults
# 31     Stephens
# 32       Troxel
# 33         Xiao
# 34          Xie
# 35          Xie
# 36         Yang
# Name: last_name, dtype: object
# 0       Bellamy
# 1        Bilker
# 2         Bryan
# 3          Chen
# 4     Ellenberg
# 5     Ellenberg
# 6          Feng
# 7        French
# 8       Gimotty
# 9           Guo
# 10          Hsu
# 11      Hubbard
# 12        Hwang
# 13        Joffe
# 14       Landis
# 15           Li
# 16           Li
# 17           Li
# 18      Localio
# 19        Mitra
# 20      Morales
# 21      Propert
# 22         Putt
# 23    Ratcliffe
# 24         Ross
# 25          Roy
# 26       Sammel
# 27         Shaw
# 28    Shinohara
# 29         Shou
# 30       Shults
# 31     Stephens
# 32       Troxel
# 33         Xiao
# 34          Xie
# 35          Xie
# 36         Yang
# Name: last_name, dtype: object
# 0       Bellamy
# 1        Bilker
# 2         Bryan
# 3          Chen
# 4     Ellenberg
# 5     Ellenberg
# 6          Feng
# 7        French
# 8       Gimotty
# 9           Guo
# 10          Hsu
# 11      Hubbard
# 12        Hwang
# 13        Joffe
# 14       Landis
# 15           Li
# 16           Li
# 17           Li
# 18      Localio
# 19        Mitra
# 20      Morales
# 21      Propert
# 22         Putt
# 23    Ratcliffe
# 24         Ross
# 25          Roy
# 26       Sammel
# 27         Shaw
# 28    Shinohara
# 29         Shou
# 30       Shults
# 31     Stephens
# 32       Troxel
# 33         Xiao
# 34          Xie
# 35          Xie
# 36         Yang
# Name: last_name, dtype: object
# 0       Bellamy
# 1        Bilker
# 2         Bryan
# 3          Chen
# 4     Ellenberg
# 5     Ellenberg
# 6          Feng
# 7        French
# 8       Gimotty
# 9           Guo
# 10          Hsu
# 11      Hubbard
# 12        Hwang
# 13        Joffe
# 14       Landis
# 15           Li
# 16           Li
# 17           Li
# 18      Localio
# 19        Mitra
# 20      Morales
# 21      Propert
# 22         Putt
# 23    Ratcliffe
# 24         Ross
# 25          Roy
# 26       Sammel
# 27         Shaw
# 28    Shinohara
# 29         Shou
# 30       Shults
# 31     Stephens
# 32       Troxel
# 33         Xiao
# 34          Xie
# 35          Xie
# 36         Yang
# Name: last_name, dtype: object
# 0       Bellamy
# 1        Bilker
# 2         Bryan
# 3          Chen
# 4     Ellenberg
# 5     Ellenberg
# 6          Feng
# 7        French
# 8       Gimotty
# 9           Guo
# 10          Hsu
# 11      Hubbard
# 12        Hwang
# 13        Joffe
# 14       Landis
# 15           Li
# 16           Li
# 17           Li
# 18      Localio
# 19        Mitra
# 20      Morales
# 21      Propert
# 22         Putt
# 23    Ratcliffe
# 24         Ross
# 25          Roy
# 26       Sammel
# 27         Shaw
# 28    Shinohara
# 29         Shou
# 30       Shults
# 31     Stephens
# 32       Troxel
# 33         Xiao
# 34          Xie
# 35          Xie
# 36         Yang
# Name: last_name, dtype: object

# %%
names = df.last_name.values
names
# Out:
# array(['Bellamy', 'Bilker', 'Bryan', 'Chen', 'Ellenberg', 'Ellenberg',
#        'Feng', 'French', 'Gimotty', 'Guo', 'Hsu', 'Hubbard', 'Hwang',
#        'Joffe', 'Landis', 'Li', 'Li', 'Li', 'Localio', 'Mitra', 'Morales',
#        'Propert', 'Putt', 'Ratcliffe', 'Ross', 'Roy', 'Sammel', 'Shaw',
#        'Shinohara', 'Shou', 'Shults', 'Stephens', 'Troxel', 'Xiao', 'Xie',
#        'Xie', 'Yang'], dtype=object)

# %%
faculty_dict = dict()

# %%
faculty_dict.keys = names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-5d6f7cd98113> in <module>()
# ----> 1 faculty_dict.keys = names
#
# AttributeError: 'dict' object attribute 'keys' is read-only
