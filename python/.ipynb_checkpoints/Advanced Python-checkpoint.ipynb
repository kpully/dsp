# %%
import pandas as pd

# %%
dir = '/Users/kpully/ds/metis/prework/dsp/python/faculty.csv'

# %%
data = pd.read_csv(dir)
df = pd.DataFrame(data)

# %%
df.columns = ['name', 'degree', 'title', 'email']
df
# Out:
#                          name               degree  \
# 0         Scarlett L. Bellamy                Sc.D.
# 1            Warren B. Bilker                Ph.D.
# 2             Matthew W Bryan                  PhD
# 3                  Jinbo Chen                Ph.D.
# 4           Susan S Ellenberg                Ph.D.
# 5          Jonas H. Ellenberg                Ph.D.
# 6                    Rui Feng                 Ph.D
# 7          Benjamin C. French                  PhD
# 8          Phyllis A. Gimotty                 Ph.D
# 9                Wensheng Guo                 Ph.D
# 10                Yenchih Hsu                Ph.D.
# 11          Rebecca A Hubbard                  PhD
# 12             Wei-Ting Hwang                Ph.D.
# 13          Marshall M. Joffe          MD MPH Ph.D
# 14          J. Richard Landis   B.S.Ed. M.S. Ph.D.
# 15                   Yimei Li                Ph.D.
# 16                 Mingyao Li                Ph.D.
# 17                 Hongzhe Li                 Ph.D
# 18         A. Russell Localio     JD MA MPH MS PhD
# 19              Nandita Mitra                Ph.D.
# 20        Knashawn H. Morales                Sc.D.
# 21       Kathleen Joy Propert                Sc.D.
# 22               Mary E. Putt              PhD ScD
# 23       Sarah Jane Ratcliffe                Ph.D.
# 24        Michelle Elana Ross                  PhD
# 25               Jason A. Roy                Ph.D.
# 26             Mary D. Sammel                Sc.D.
# 27            Pamela Ann Shaw                  PhD
# 28  Russell Takeshi Shinohara                    0
# 29              Haochang Shou                Ph.D.
# 30             Justine Shults                Ph.D.
# 31        Alisa Jane Stephens                Ph.D.
# 32         Andrea Beth Troxel                  ScD
# 33                   Rui Xiao                  PhD
# 34        Sharon Xiangwen Xie                Ph.D.
# 35                  Dawei Xie                  PhD
# 36           Wei (Peter) Yang                Ph.D.
#
#                                    title                        email
# 0   Associate Professor of Biostatistics  bellamys@mail.med.upenn.edu
# 1             Professor of Biostatistics             warren@upenn.edu
# 2   Assistant Professor of Biostatistics            bryanma@upenn.edu
# 3   Associate Professor of Biostatistics           jinboche@upenn.edu
# 4             Professor of Biostatistics           sellenbe@upenn.edu
# 5             Professor of Biostatistics  jellenbe@mail.med.upenn.edu
# 6   Assistant Professor of Biostatistics            ruifeng@upenn.edu
# 7   Associate Professor of Biostatistics  bcfrench@mail.med.upenn.edu
# 8             Professor of Biostatistics           pgimotty@upenn.edu
# 9             Professor of Biostatistics      wguo@mail.med.upenn.edu
# 10  Assistant Professor of Biostatistics      hsu9@mail.med.upenn.edu
# 11  Associate Professor of Biostatistics     rhubb@mail.med.upenn.edu
# 12  Associate Professor of Biostatistics    whwang@mail.med.upenn.edu
# 13            Professor of Biostatistics    mjoffe@mail.med.upenn.edu
# 14            Professor of Biostatistics  jrlandis@mail.med.upenn.edu
# 15  Assistant Professor of Biostatistics          liy3@email.chop.edu
# 16  Associate Professor of Biostatistics   mingyao@mail.med.upenn.edu
# 17            Professor of Biostatistics            hongzhe@upenn.edu
# 18  Associate Professor of Biostatistics           rlocalio@upenn.edu
# 19  Associate Professor of Biostatistics  nanditam@mail.med.upenn.edu
# 20  Associate Professor of Biostatistics  knashawn@mail.med.upenn.edu
# 21            Professor of Biostatistics   propert@mail.med.upenn.edu
# 22            Professor of Biostatistics     mputt@mail.med.upenn.edu
# 23  Associate Professor of Biostatistics           sratclif@upenn.edu
# 24  Assistant Professor is Biostatistics           michross@upenn.edu
# 25  Associate Professor of Biostatistics     jaroy@mail.med.upenn.edu
# 26            Professor of Biostatistics   msammel@cceb.med.upenn.edu
# 27  Assistant Professor of Biostatistics              shawp@upenn.edu
# 28  Assistant Professor of Biostatistics      rshi@mail.med.upenn.edu
# 29  Assistant Professor of Biostatistics     hshou@mail.med.upenn.edu
# 30            Professor of Biostatistics   jshults@mail.med.upenn.edu
# 31  Assistant Professor of Biostatistics  alisaste@mail.med.upenn.edu
# 32            Professor of Biostatistics   atroxel@mail.med.upenn.edu
# 33  Assistant Professor of Biostatistics     rxiao@mail.med.upenn.edu
# 34  Associate Professor of Biostatistics      sxie@mail.med.upenn.edu
# 35  Assistant Professor of Biostatistics               dxie@upenn.edu
# 36  Assistant Professor of Biostatistics   weiyang@mail.med.upenn.edu

# %%
titles_unique = set()
titles_all = list()
for title in df.title:
    of = title.find('of ')
    title = title[:of]
    #print title
    titles_all.append(title.strip())
    titles_unique.add(title.strip())
    df['stripped title'] = title.strip()

# %%
df.head()
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email       stripped title
# 0  bellamys@mail.med.upenn.edu  Assistant Professor
# 1             warren@upenn.edu  Assistant Professor
# 2            bryanma@upenn.edu  Assistant Professor
# 3           jinboche@upenn.edu  Assistant Professor
# 4           sellenbe@upenn.edu  Assistant Professor

# %%
len(titles_unique)
titles_unique
# Out:
# {'Assistant Professor',
#  'Assistant Professor is Biostatistic',
#  'Associate Professor',
#  'Professor'}

# %%
degrees_unique = set()
degrees_all = list()
for degree in df.degree:
    degree_list = degree.lower().strip().replace('.', '').split(' ')
    for degree in degree_list:
        degrees_unique.add(degree)
        degrees_all.append(degree)

# %%
degrees_unique.remove('0')

# %%
print len(degrees_unique)
print degrees_unique
# Out:
# 8
# set(['md', 'ma', 'scd', 'bsed', 'phd', 'mph', 'ms', 'jd'])

# %%
print "PhDs: " + str(degrees_all.count('phd'))
print "MDs: " + str(degrees_all.count('md'))
print "MAs: " + str(degrees_all.count('ma'))
print "BSEds: " + str(degrees_all.count('bsed'))
print "JDs: " + str(degrees_all.count('jd'))
print "MPHs: " + str(degrees_all.count('mph'))
print "SCDs: " + str(degrees_all.count('scd'))
print "MSs: " + str(degrees_all.count('ms'))
# Out:
# PhDs: 31
# MDs: 1
# MAs: 1
# BSEds: 1
# JDs: 1
# MPHs: 2
# SCDs: 6
# MSs: 2

# %%
domains = set()
for email in df.email:
    cutoff = email.find('@')
    domain = email[cutoff:]
    domains.add(domain)
domains
# Out:
# {'@cceb.med.upenn.edu', '@email.chop.edu', '@mail.med.upenn.edu', '@upenn.edu'}

# %%
#df.email.to_csv('emails.csv')
#how to get it to a list without the index?

# %%
emails = df.email.tolist

# %%
new_dict = dict()
df.head()
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email       stripped title
# 0  bellamys@mail.med.upenn.edu  Assistant Professor
# 1             warren@upenn.edu  Assistant Professor
# 2            bryanma@upenn.edu  Assistant Professor
# 3           jinboche@upenn.edu  Assistant Professor
# 4           sellenbe@upenn.edu  Assistant Professor

# %%
first_names = list()
last_names = list()
for name in df.name:
    space1 = name.find(' ')
    first_name = name[:space1]
    remaining_name = name[space1 + 1:]
    space2 = remaining_name.find(' ')
    last_name = remaining_name[space2+1:]
    #print 'BREAKDOWN: original name = ' + name + ' / first name = ' + first_name + ' / last name = ' + last_name
    first_names.append(first_name)
    last_names.append(last_name)
df['first_name'] = first_names
df['last_name'] = last_names
df.head(6)
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
# 5   Jonas H. Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email       stripped title first_name  last_name
# 0  bellamys@mail.med.upenn.edu  Assistant Professor   Scarlett    Bellamy
# 1             warren@upenn.edu  Assistant Professor     Warren     Bilker
# 2            bryanma@upenn.edu  Assistant Professor    Matthew      Bryan
# 3           jinboche@upenn.edu  Assistant Professor      Jinbo       Chen
# 4           sellenbe@upenn.edu  Assistant Professor      Susan  Ellenberg
# 5  jellenbe@mail.med.upenn.edu  Assistant Professor      Jonas  Ellenberg

# %%
#faculty_dict = df2.set_index('last_name').T.to_dict('list')

# %%
d= dict([(i,[a,b,c ]) for i, a,b,c in zip(df.last_name, df.degree, df['stripped title'],df.email )])
d
# Out:
# {'Bellamy': [' Sc.D.', 'Assistant Professor', 'bellamys@mail.med.upenn.edu'],
#  'Bilker': ['Ph.D.', 'Assistant Professor', 'warren@upenn.edu'],
#  'Bryan': [' PhD', 'Assistant Professor', 'bryanma@upenn.edu'],
#  'Chen': [' Ph.D.', 'Assistant Professor', 'jinboche@upenn.edu'],
#  'Ellenberg': [' Ph.D.', 'Assistant Professor', 'jellenbe@mail.med.upenn.edu'],
#  'Feng': [' Ph.D', 'Assistant Professor', 'ruifeng@upenn.edu'],
#  'French': [' PhD', 'Assistant Professor', 'bcfrench@mail.med.upenn.edu'],
#  'Gimotty': [' Ph.D', 'Assistant Professor', 'pgimotty@upenn.edu'],
#  'Guo': [' Ph.D', 'Assistant Professor', 'wguo@mail.med.upenn.edu'],
#  'Hsu': [' Ph.D.', 'Assistant Professor', 'hsu9@mail.med.upenn.edu'],
#  'Hubbard': [' PhD', 'Assistant Professor', 'rhubb@mail.med.upenn.edu'],
#  'Hwang': [' Ph.D.', 'Assistant Professor', 'whwang@mail.med.upenn.edu'],
#  'Joffe': [' MD MPH Ph.D', 'Assistant Professor', 'mjoffe@mail.med.upenn.edu'],
#  'Landis': [' B.S.Ed. M.S. Ph.D.',
#   'Assistant Professor',
#   'jrlandis@mail.med.upenn.edu'],
#  'Li': [' Ph.D', 'Assistant Professor', 'hongzhe@upenn.edu'],
#  'Localio': [' JD MA MPH MS PhD', 'Assistant Professor', 'rlocalio@upenn.edu'],
#  'Mitra': [' Ph.D.', 'Assistant Professor', 'nanditam@mail.med.upenn.edu'],
#  'Morales': [' Sc.D.', 'Assistant Professor', 'knashawn@mail.med.upenn.edu'],
#  'Propert': [' Sc.D.', 'Assistant Professor', 'propert@mail.med.upenn.edu'],
#  'Putt': [' PhD ScD', 'Assistant Professor', 'mputt@mail.med.upenn.edu'],
#  'Ratcliffe': [' Ph.D.', 'Assistant Professor', 'sratclif@upenn.edu'],
#  'Ross': [' PhD', 'Assistant Professor', 'michross@upenn.edu'],
#  'Roy': [' Ph.D.', 'Assistant Professor', 'jaroy@mail.med.upenn.edu'],
#  'Sammel': [' Sc.D.', 'Assistant Professor', 'msammel@cceb.med.upenn.edu'],
#  'Shaw': [' PhD', 'Assistant Professor', 'shawp@upenn.edu'],
#  'Shinohara': ['0', 'Assistant Professor', 'rshi@mail.med.upenn.edu'],
#  'Shou': [' Ph.D.', 'Assistant Professor', 'hshou@mail.med.upenn.edu'],
#  'Shults': [' Ph.D.', 'Assistant Professor', 'jshults@mail.med.upenn.edu'],
#  'Stephens': [' Ph.D.', 'Assistant Professor', 'alisaste@mail.med.upenn.edu'],
#  'Troxel': [' ScD', 'Assistant Professor', 'atroxel@mail.med.upenn.edu'],
#  'Xiao': [' PhD', 'Assistant Professor', 'rxiao@mail.med.upenn.edu'],
#  'Xie': [' PhD', 'Assistant Professor', 'dxie@upenn.edu'],
#  'Yang': [' Ph.D.', 'Assistant Professor', 'weiyang@mail.med.upenn.edu']}

# %%
#d= dict([(i,y,[a,b,c ]) for i,y a,b,c in zip(df.last_name, df.first_name, df.degree, df['stripped title'],df.email )])
#d

# %%
# Select just the columns we want and put them in order
faculty2 = df[['last_name','degree','stripped title','email']]

# Here is the command I was referencing
faculty_dict = ( faculty2                             # our dataframe
                 .set_index('last_name')              # set the index column
                 .groupby(level=0)                    # groupby, note that 'last_name' is level 0 of index
                 .apply(lambda x: x.values.tolist())  # this will be applied to each sub-dataframe created by grouping,
                                                      # it handles the conversion to an array (values) and then a list
                                                      # then pandas will recombine everything back into a dataframe per-groupby
                 .to_dict()                           # finally we make a dictionary out of it!
               )

# %%
faculty_dict
# Out:
# {'Bellamy': [[' Sc.D.', 'Assistant Professor', 'bellamys@mail.med.upenn.edu']],
#  'Bilker': [['Ph.D.', 'Assistant Professor', 'warren@upenn.edu']],
#  'Bryan': [[' PhD', 'Assistant Professor', 'bryanma@upenn.edu']],
#  'Chen': [[' Ph.D.', 'Assistant Professor', 'jinboche@upenn.edu']],
#  'Ellenberg': [[' Ph.D.', 'Assistant Professor', 'sellenbe@upenn.edu'],
#   [' Ph.D.', 'Assistant Professor', 'jellenbe@mail.med.upenn.edu']],
#  'Feng': [[' Ph.D', 'Assistant Professor', 'ruifeng@upenn.edu']],
#  'French': [[' PhD', 'Assistant Professor', 'bcfrench@mail.med.upenn.edu']],
#  'Gimotty': [[' Ph.D', 'Assistant Professor', 'pgimotty@upenn.edu']],
#  'Guo': [[' Ph.D', 'Assistant Professor', 'wguo@mail.med.upenn.edu']],
#  'Hsu': [[' Ph.D.', 'Assistant Professor', 'hsu9@mail.med.upenn.edu']],
#  'Hubbard': [[' PhD', 'Assistant Professor', 'rhubb@mail.med.upenn.edu']],
#  'Hwang': [[' Ph.D.', 'Assistant Professor', 'whwang@mail.med.upenn.edu']],
#  'Joffe': [[' MD MPH Ph.D',
#    'Assistant Professor',
#    'mjoffe@mail.med.upenn.edu']],
#  'Landis': [[' B.S.Ed. M.S. Ph.D.',
#    'Assistant Professor',
#    'jrlandis@mail.med.upenn.edu']],
#  'Li': [[' Ph.D.', 'Assistant Professor', 'liy3@email.chop.edu'],
#   [' Ph.D.', 'Assistant Professor', 'mingyao@mail.med.upenn.edu'],
#   [' Ph.D', 'Assistant Professor', 'hongzhe@upenn.edu']],
#  'Localio': [[' JD MA MPH MS PhD',
#    'Assistant Professor',
#    'rlocalio@upenn.edu']],
#  'Mitra': [[' Ph.D.', 'Assistant Professor', 'nanditam@mail.med.upenn.edu']],
#  'Morales': [[' Sc.D.', 'Assistant Professor', 'knashawn@mail.med.upenn.edu']],
#  'Propert': [[' Sc.D.', 'Assistant Professor', 'propert@mail.med.upenn.edu']],
#  'Putt': [[' PhD ScD', 'Assistant Professor', 'mputt@mail.med.upenn.edu']],
#  'Ratcliffe': [[' Ph.D.', 'Assistant Professor', 'sratclif@upenn.edu']],
#  'Ross': [[' PhD', 'Assistant Professor', 'michross@upenn.edu']],
#  'Roy': [[' Ph.D.', 'Assistant Professor', 'jaroy@mail.med.upenn.edu']],
#  'Sammel': [[' Sc.D.', 'Assistant Professor', 'msammel@cceb.med.upenn.edu']],
#  'Shaw': [[' PhD', 'Assistant Professor', 'shawp@upenn.edu']],
#  'Shinohara': [['0', 'Assistant Professor', 'rshi@mail.med.upenn.edu']],
#  'Shou': [[' Ph.D.', 'Assistant Professor', 'hshou@mail.med.upenn.edu']],
#  'Shults': [[' Ph.D.', 'Assistant Professor', 'jshults@mail.med.upenn.edu']],
#  'Stephens': [[' Ph.D.',
#    'Assistant Professor',
#    'alisaste@mail.med.upenn.edu']],
#  'Troxel': [[' ScD', 'Assistant Professor', 'atroxel@mail.med.upenn.edu']],
#  'Xiao': [[' PhD', 'Assistant Professor', 'rxiao@mail.med.upenn.edu']],
#  'Xie': [[' Ph.D.', 'Assistant Professor', 'sxie@mail.med.upenn.edu'],
#   [' PhD', 'Assistant Professor', 'dxie@upenn.edu']],
#  'Yang': [[' Ph.D.', 'Assistant Professor', 'weiyang@mail.med.upenn.edu']]}

# %%
# Here is the command I was referencing
faculty2 = df[['first_name', 'last_name','degree','stripped title','email']]

professor_dict = ( faculty2
                 .set_index(['first_name', 'last_name'])
                 .groupby(level=[0, 1])                             # two index levels!
                 .apply(lambda x: x.values.tolist())
                 .to_dict()
               )

# %%
professor_dict
# Out:
# {('A.',
#   'Localio'): [[' JD MA MPH MS PhD',
#    'Assistant Professor',
#    'rlocalio@upenn.edu']],
#  ('Alisa',
#   'Stephens'): [[' Ph.D.',
#    'Assistant Professor',
#    'alisaste@mail.med.upenn.edu']],
#  ('Andrea',
#   'Troxel'): [[' ScD', 'Assistant Professor', 'atroxel@mail.med.upenn.edu']],
#  ('Benjamin',
#   'French'): [[' PhD', 'Assistant Professor', 'bcfrench@mail.med.upenn.edu']],
#  ('Dawei', 'Xie'): [[' PhD', 'Assistant Professor', 'dxie@upenn.edu']],
#  ('Haochang',
#   'Shou'): [[' Ph.D.', 'Assistant Professor', 'hshou@mail.med.upenn.edu']],
#  ('Hongzhe', 'Li'): [[' Ph.D', 'Assistant Professor', 'hongzhe@upenn.edu']],
#  ('J.',
#   'Landis'): [[' B.S.Ed. M.S. Ph.D.',
#    'Assistant Professor',
#    'jrlandis@mail.med.upenn.edu']],
#  ('Jason',
#   'Roy'): [[' Ph.D.', 'Assistant Professor', 'jaroy@mail.med.upenn.edu']],
#  ('Jinbo', 'Chen'): [[' Ph.D.', 'Assistant Professor', 'jinboche@upenn.edu']],
#  ('Jonas',
#   'Ellenberg'): [[' Ph.D.',
#    'Assistant Professor',
#    'jellenbe@mail.med.upenn.edu']],
#  ('Justine',
#   'Shults'): [[' Ph.D.', 'Assistant Professor', 'jshults@mail.med.upenn.edu']],
#  ('Kathleen',
#   'Propert'): [[' Sc.D.',
#    'Assistant Professor',
#    'propert@mail.med.upenn.edu']],
#  ('Knashawn',
#   'Morales'): [[' Sc.D.',
#    'Assistant Professor',
#    'knashawn@mail.med.upenn.edu']],
#  ('Marshall',
#   'Joffe'): [[' MD MPH Ph.D',
#    'Assistant Professor',
#    'mjoffe@mail.med.upenn.edu']],
#  ('Mary',
#   'Putt'): [[' PhD ScD', 'Assistant Professor', 'mputt@mail.med.upenn.edu']],
#  ('Mary',
#   'Sammel'): [[' Sc.D.', 'Assistant Professor', 'msammel@cceb.med.upenn.edu']],
#  ('Matthew', 'Bryan'): [[' PhD', 'Assistant Professor', 'bryanma@upenn.edu']],
#  ('Michelle', 'Ross'): [[' PhD', 'Assistant Professor', 'michross@upenn.edu']],
#  ('Mingyao',
#   'Li'): [[' Ph.D.', 'Assistant Professor', 'mingyao@mail.med.upenn.edu']],
#  ('Nandita',
#   'Mitra'): [[' Ph.D.', 'Assistant Professor', 'nanditam@mail.med.upenn.edu']],
#  ('Pamela', 'Shaw'): [[' PhD', 'Assistant Professor', 'shawp@upenn.edu']],
#  ('Phyllis',
#   'Gimotty'): [[' Ph.D', 'Assistant Professor', 'pgimotty@upenn.edu']],
#  ('Rebecca',
#   'Hubbard'): [[' PhD', 'Assistant Professor', 'rhubb@mail.med.upenn.edu']],
#  ('Rui', 'Feng'): [[' Ph.D', 'Assistant Professor', 'ruifeng@upenn.edu']],
#  ('Rui',
#   'Xiao'): [[' PhD', 'Assistant Professor', 'rxiao@mail.med.upenn.edu']],
#  ('Russell',
#   'Shinohara'): [['0', 'Assistant Professor', 'rshi@mail.med.upenn.edu']],
#  ('Sarah',
#   'Ratcliffe'): [[' Ph.D.', 'Assistant Professor', 'sratclif@upenn.edu']],
#  ('Scarlett',
#   'Bellamy'): [[' Sc.D.',
#    'Assistant Professor',
#    'bellamys@mail.med.upenn.edu']],
#  ('Sharon',
#   'Xie'): [[' Ph.D.', 'Assistant Professor', 'sxie@mail.med.upenn.edu']],
#  ('Susan',
#   'Ellenberg'): [[' Ph.D.', 'Assistant Professor', 'sellenbe@upenn.edu']],
#  ('Warren', 'Bilker'): [['Ph.D.', 'Assistant Professor', 'warren@upenn.edu']],
#  ('Wei',
#   'Yang'): [[' Ph.D.', 'Assistant Professor', 'weiyang@mail.med.upenn.edu']],
#  ('Wei-Ting',
#   'Hwang'): [[' Ph.D.', 'Assistant Professor', 'whwang@mail.med.upenn.edu']],
#  ('Wensheng',
#   'Guo'): [[' Ph.D', 'Assistant Professor', 'wguo@mail.med.upenn.edu']],
#  ('Yenchih',
#   'Hsu'): [[' Ph.D.', 'Assistant Professor', 'hsu9@mail.med.upenn.edu']],
#  ('Yimei', 'Li'): [[' Ph.D.', 'Assistant Professor', 'liy3@email.chop.edu']]}

# %%
# Here is the command I was referencing
#faculty2 = df[['first_name', 'last_name','degree','stripped title','email']]

professor_dict2 = ( faculty2
                 .set_index(['first_name', 'last_name'])
                 .groupby(level=[1, 0])                             # two index levels!
                 .apply(lambda x: x.values.tolist())
                 .to_dict()
               )

# %%
professor_dict2
# Out:
# {('Bellamy',
#   'Scarlett'): [[' Sc.D.',
#    'Assistant Professor',
#    'bellamys@mail.med.upenn.edu']],
#  ('Bilker', 'Warren'): [['Ph.D.', 'Assistant Professor', 'warren@upenn.edu']],
#  ('Bryan', 'Matthew'): [[' PhD', 'Assistant Professor', 'bryanma@upenn.edu']],
#  ('Chen', 'Jinbo'): [[' Ph.D.', 'Assistant Professor', 'jinboche@upenn.edu']],
#  ('Ellenberg',
#   'Jonas'): [[' Ph.D.', 'Assistant Professor', 'jellenbe@mail.med.upenn.edu']],
#  ('Ellenberg',
#   'Susan'): [[' Ph.D.', 'Assistant Professor', 'sellenbe@upenn.edu']],
#  ('Feng', 'Rui'): [[' Ph.D', 'Assistant Professor', 'ruifeng@upenn.edu']],
#  ('French',
#   'Benjamin'): [[' PhD',
#    'Assistant Professor',
#    'bcfrench@mail.med.upenn.edu']],
#  ('Gimotty',
#   'Phyllis'): [[' Ph.D', 'Assistant Professor', 'pgimotty@upenn.edu']],
#  ('Guo',
#   'Wensheng'): [[' Ph.D', 'Assistant Professor', 'wguo@mail.med.upenn.edu']],
#  ('Hsu',
#   'Yenchih'): [[' Ph.D.', 'Assistant Professor', 'hsu9@mail.med.upenn.edu']],
#  ('Hubbard',
#   'Rebecca'): [[' PhD', 'Assistant Professor', 'rhubb@mail.med.upenn.edu']],
#  ('Hwang',
#   'Wei-Ting'): [[' Ph.D.',
#    'Assistant Professor',
#    'whwang@mail.med.upenn.edu']],
#  ('Joffe',
#   'Marshall'): [[' MD MPH Ph.D',
#    'Assistant Professor',
#    'mjoffe@mail.med.upenn.edu']],
#  ('Landis',
#   'J.'): [[' B.S.Ed. M.S. Ph.D.',
#    'Assistant Professor',
#    'jrlandis@mail.med.upenn.edu']],
#  ('Li', 'Hongzhe'): [[' Ph.D', 'Assistant Professor', 'hongzhe@upenn.edu']],
#  ('Li',
#   'Mingyao'): [[' Ph.D.',
#    'Assistant Professor',
#    'mingyao@mail.med.upenn.edu']],
#  ('Li', 'Yimei'): [[' Ph.D.', 'Assistant Professor', 'liy3@email.chop.edu']],
#  ('Localio',
#   'A.'): [[' JD MA MPH MS PhD', 'Assistant Professor', 'rlocalio@upenn.edu']],
#  ('Mitra',
#   'Nandita'): [[' Ph.D.',
#    'Assistant Professor',
#    'nanditam@mail.med.upenn.edu']],
#  ('Morales',
#   'Knashawn'): [[' Sc.D.',
#    'Assistant Professor',
#    'knashawn@mail.med.upenn.edu']],
#  ('Propert',
#   'Kathleen'): [[' Sc.D.',
#    'Assistant Professor',
#    'propert@mail.med.upenn.edu']],
#  ('Putt',
#   'Mary'): [[' PhD ScD', 'Assistant Professor', 'mputt@mail.med.upenn.edu']],
#  ('Ratcliffe',
#   'Sarah'): [[' Ph.D.', 'Assistant Professor', 'sratclif@upenn.edu']],
#  ('Ross', 'Michelle'): [[' PhD', 'Assistant Professor', 'michross@upenn.edu']],
#  ('Roy',
#   'Jason'): [[' Ph.D.', 'Assistant Professor', 'jaroy@mail.med.upenn.edu']],
#  ('Sammel',
#   'Mary'): [[' Sc.D.', 'Assistant Professor', 'msammel@cceb.med.upenn.edu']],
#  ('Shaw', 'Pamela'): [[' PhD', 'Assistant Professor', 'shawp@upenn.edu']],
#  ('Shinohara',
#   'Russell'): [['0', 'Assistant Professor', 'rshi@mail.med.upenn.edu']],
#  ('Shou',
#   'Haochang'): [[' Ph.D.', 'Assistant Professor', 'hshou@mail.med.upenn.edu']],
#  ('Shults',
#   'Justine'): [[' Ph.D.',
#    'Assistant Professor',
#    'jshults@mail.med.upenn.edu']],
#  ('Stephens',
#   'Alisa'): [[' Ph.D.', 'Assistant Professor', 'alisaste@mail.med.upenn.edu']],
#  ('Troxel',
#   'Andrea'): [[' ScD', 'Assistant Professor', 'atroxel@mail.med.upenn.edu']],
#  ('Xiao',
#   'Rui'): [[' PhD', 'Assistant Professor', 'rxiao@mail.med.upenn.edu']],
#  ('Xie', 'Dawei'): [[' PhD', 'Assistant Professor', 'dxie@upenn.edu']],
#  ('Xie',
#   'Sharon'): [[' Ph.D.', 'Assistant Professor', 'sxie@mail.med.upenn.edu']],
#  ('Yang',
#   'Wei'): [[' Ph.D.', 'Assistant Professor', 'weiyang@mail.med.upenn.edu']]}
